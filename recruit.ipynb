# %% [markdown]
# # Main algorithm

# %% [markdown]
# ## 1. DB 불러오기

# %%
import pymysql

# 데이터베이스 연결
db = pymysql.connect(host='recruit.cob9hpevtink.ap-northeast-2.rds.amazonaws.com', database='new_schema', port=3306, user='admin', password='201912343')
cursor = db.cursor()

try:
    # SQL 쿼리 실행
    sql = 'SELECT * FROM recuity'
    cursor.execute(sql)
    result = cursor.fetchall()
    for data in result:
        print(data)
finally:
    # 데이터베이스 연결과 커서 닫기
    cursor.close()
    db.close()
# Out:
# ('노타', 'Trust\n노타 전원은 양방향 신뢰를 기반으로, 한 곳을 보고 있다는 믿음을 가지고 일해요. 서로의 충돌도 더욱 나아지기 위한 과정임을 알기에 적극적으로 얘기하며 토론할 수 있어요.\nGood Influence\n노타는 세상에 좋은 영향을 주기 위해서 존재해요. 우리는 모든 일을 혼자 할 수 없음을 인지하고 함께 일하고 싶은 동료가 되고자 노력해요.\nAutonomy & Responsibility\n노타는 자율성에서 나오는 시너지와 효율을 믿어요. 엄격한 규칙에 의존하지 않기 때문에, 더 몰입할 수 있어요.\nCuriosity\n노타의 모든 기술은 호기심과 더 나은 일상에 대한 갈망에서 시작했어요. 모든 일에 대한 호기심은, 노타에서 일하는 사람이라면 꼭 가져야 할 덕목이에요.\n', '# 우리는 인공지능 모델 최적화 기술을 기반으로 \nAI 보편화를 추구하는 기업, 노타입니다.\n\n**노타는 다양한 산업과 애플리케이션 전반에 걸쳐 AI 사용을 보편화하여 \n모든 사람에게 어디에서나 AI를 활용할 수 있는 것을 목표로 합니다.**\n\n노타의 핵심 제품은 인공지능 원천기술인 딥러닝 모델 경량화 기술을 기반으로 AI 모델 개발 프로세스를 자동화 하는 AI 최적화 플랫폼, **[넷츠프레소(NetsPresso)](https://netspresso.ai/)**입니다. 더불어 노타의 AI 최적화 기술은 지능형 교통 시스템 및 저전력 운전자 모니터링 시스템을 포함한 다양한 AI 솔루션 또한 제안합니다.\n\n국내 스타트업으로는 최초로 삼성과 LG의 투자 유치 기록을 보유하고 있으며, 네이버 D2SF가 최초로 투자한 스타트업입니다. 노타는 세계 시장을 선도하는 NVIDIA, Intel, ARM 등과 같은 기업들과 강력한 파트너십을 구축하여 해외 AI 시장 진출에 박차를 가하고 있습니다.', 'Ownership\n\n노타크루가 오너십을 가진다면 회사의 발전이 본인의 발전이라고 느낄 수 있고, 성장에 더욱 보람을 느낄 수 있어요. 우리 회사는 노타크루가 
# ...

# %%
import pymysql

# 데이터베이스 연결
db = pymysql.connect(host='recruit.cob9hpevtink.ap-northeast-2.rds.amazonaws.com', database='new_schema', port=3306, user='admin', password='201912343')
cursor = db.cursor()

try:
    # SQL 쿼리 실행
    sql = "select corp_name from recuity;"
    cursor.execute(sql)
    result = cursor.fetchall()
    for corp_name in result:
        print(corp_name)
finally:
    # 데이터베이스 연결과 커서 닫기
    cursor.close()
    db.close()
# Out:
# ('노타',)
# ('라포랩스',)
# ('레몬베이스',)
# ('뤼튼',)
# ('배민 프랜차이즈시스템',)
# ('오피지지',)
# ('왓챠',)
# ('웨이브',)
# ('인프런',)
# ('팀스파르타',)

# %% [markdown]
# 모든 회사에 대한 정보를 db에서 가져오고, json 파일 형식으로 저장

# %%
import os
import pymysql
import json

# 데이터베이스 연결 정보 설정
db_config = {
    'host': 'recruit.cob9hpevtink.ap-northeast-2.rds.amazonaws.com',
    'database': 'new_schema',
    'port': 3306,
    'user': 'admin',
    'password': '201912343'
}

# 데이터베이스 연결
db = pymysql.connect(**db_config)
cursor = db.cursor()

# 폴더 경로 생성
output_folder = 'data'
os.makedirs(output_folder, exist_ok=True)

try:
    # 고유한 corp_name 값 가져오기
    sql = 'SELECT DISTINCT corp_name FROM recuity'
    cursor.execute(sql)
    
    corp_names = cursor.fetchall()
    
    for corp_name in corp_names:
        # 각 corp_name에 대한 JSON 파일 경로 생성
        json_file_name = os.path.join(output_folder, f'{corp_name[0]}.json')
        
        # SQL 쿼리 실행 (해당 corp_name을 가진 행을 가져옴)
        sql = f'SELECT * FROM recuity WHERE corp_name = %s'
        cursor.execute(sql, (corp_name[0],))
        
        # 결과를 JSON 형식으로 저장할 딕셔너리 초기화
        data_dict = {}
        
        # 결과 가져오기
        result = cursor.fetchall()
        for row in result:
            # 각 행의 데이터를 딕셔너리에 추가
            data_dict['corp_name'] = row[0]
            data_dict['value'] = row[1]
            data_dict['intro'] = row[2]
            data_dict['personality'] = row[3]
            data_dict['benefit'] = row[4]
            data_dict['culture'] = row[5]
            data_dict['location'] = row[6]
            data_dict['condition'] = row[7]
            # ... 필요한 모든 컬럼 추가
        
        # JSON 파일로 저장
        with open(json_file_name, 'w', encoding='utf-8') as json_file:
            json.dump(data_dict, json_file, ensure_ascii=False, indent=4)

finally:
    # 데이터베이스 연결 닫기
    db.close()

# %% [markdown]
# 텍스트 파일로 저장

# %%
import os
import pymysql

# 데이터베이스 연결 정보 설정
db_config = {
    'host': 'recruit.cob9hpevtink.ap-northeast-2.rds.amazonaws.com',
    'database': 'new_schema',
    'port': 3306,
    'user': 'admin',
    'password': '201912343'
}

# 데이터베이스 연결
db = pymysql.connect(**db_config)
cursor = db.cursor()

# 폴더 경로 생성
output_folder = 'txt_data'
os.makedirs(output_folder, exist_ok=True)

try:
    # 고유한 corp_name 값 가져오기
    sql = 'SELECT DISTINCT corp_name FROM recuity'
    cursor.execute(sql)
    
    corp_names = cursor.fetchall()
    
    for corp_name in corp_names:
        # 각 corp_name에 대한 TXT 파일 경로 생성
        txt_file_name = os.path.join(output_folder, f'{corp_name[0]}.txt')
        
        # SQL 쿼리 실행 (해당 corp_name을 가진 행을 가져옴)
        sql = f'SELECT * FROM recuity WHERE corp_name = %s'
        cursor.execute(sql, (corp_name[0],))
        
        # 결과를 TXT 파일로 저장
        with open(txt_file_name, 'w', encoding='utf-8') as txt_file:
            # Get the column names
            column_names = [desc[0] for desc in cursor.description]
            txt_file.write(', '.join(column_names) + '\n')
            
            result = cursor.fetchall()
            for row in result:
                # Write column names and corresponding data values
                for col_name, data in zip(column_names, row):
                    txt_file.write(f'{col_name}: {data}\n')
                txt_file.write('\n')  # 각 회사 데이터 구분을 위한 줄 바꿈 추가

finally:
    # 데이터베이스 연결 닫기
    db.close()

# %% [markdown]
# 데이터프레임으로 생성

# %%
import os
import pandas as pd

# JSON 파일이 저장된 폴더 경로
json_folder = 'data'

# 폴더 내 모든 JSON 파일을 읽어와서 DataFrame으로 저장
data_frames = {}  # DataFrame을 저장할 딕셔너리

for json_file_name in os.listdir(json_folder):
    # 파일 경로 생성
    file_path = os.path.join(json_folder, json_file_name)
    
    # JSON 파일을 DataFrame으로 읽어오기
    with open(file_path, 'r', encoding='utf-8') as json_file:
        data = json.load(json_file)
        corp_name = data['corp_name']  # 회사 이름을 키로 사용
        
        # 데이터를 DataFrame으로 변환
        df = pd.DataFrame(data, index=[0])  # 데이터가 한 행에 있으므로 index=[0] 사용
        
        # 딕셔너리에 DataFrame 저장 (회사 이름을 키로 사용)
        data_frames[corp_name] = df

# 각 DataFrame에 접근하여 활용 가능
for corp_name, df in data_frames.items():
    print(f"DataFrame for {corp_name}:")
    print(df)
# Out:
# DataFrame for 오피지지:
#   corp_name                                              value  \
# 0      오피지지  변화를 두려워하기보다 패러다임을 바꾸고, 어려운 목표는 포기하지 않고 즐기며 달성합...
#
#                                                intro  \
# 0  오피지지는  \n전세계 유저들에게 \n전에 없던 최고의 게임 플레이 경험을 제공하는...
#
#                                          personality  \
# 0  우리는 변화를 두려워하기보다 패러다임을 바꾸고, 어려운 목표는 포기하지 않고 즐기며...
#
#                      benefit  \
# 0  완전 자율 근무 제도, 무제한 업무 지원 제도
#
#                                              culture         location  \
# 0  타인이 정하지 않고 스스로 결정하며, 나의 일에 책임을 다합니다\n어떤 조직에선 빠...  서울 강남구 테헤란로 507
#
#                                            condition
# 0  우리는 변화를 두려워하기보다 패러다임을 바꾸고, 어려운 목표는 포기하지 않고 즐기며...
# DataFrame for 라포랩스:
#   corp_name                                              value  \
# 0      라포랩스  Integrity\n앞으로 언급할 모든 가치를 위한 바탕으로서, 라포랩스는 Inte...
#
#                                                intro  \
# 0  4050 고객들도 더 편하게, 더 쉽게, 더 안전하게 "원하는 옷"을 살 수 있어야...
#
# ...

# %% [markdown]
# # 랭체인

# %%
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.llms import OpenAI
from langchain.chains import RetrievalQA
from langchain.document_loaders import TextLoader
from langchain.document_loaders import DirectoryLoader

# %% [markdown]
# 데이터 로드

# %%
loader = DirectoryLoader('./data', glob='*.json', loader_cls=TextLoader)

documents = loader.load()

len(documents)
# Out:
# 10

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200) #1000자 씩 끊되, 200자 씩 겹치게 만든다.
texts = text_splitter.split_documents(documents)

len(texts)
# Out:
# 43

# %%
texts[4]
# Out:
# Document(page_content='* 성공 확률 = 기대 이익을 계산해서 임팩트가 큰 일부터 합니다.\\n Act and Deliver Results\\n하루라도 빠르게 실행하여 결과를 얻어내면, 그 뒤에 모든 일에 긍정적인 영향을 미칩니다.\\n그러기 위해서는 얻고자 하는 결과를 분명히하고, 그 범위를 축소시켜 실행을 작은 단위로 나누고 강력한 실행력으로 결과를 얻어내야 합니다. 완벽하게 실험하기 위해서 우선 데이터를 뽑고, 실험 대상을 명확하게 규정해서 하기 보다 우선 500명에게 바로 적용하고 결과를 보는게 더 낫습니다.\\n Moon-shot\\n우리는 가슴이 뛰고, 인생의 일부를 투자할 정도로 쫓을 만한 높은 목표를 추구합니다.\\n달성할 수 있는 쉬운 목표를 잡기보다는, 달성이 거의 불가능 해보이는 목표를 설정하고 이를 이루고자 하는 과정을 통해 상상을 뛰어 넘는 폭의 성장을 이뤄냅니다.\\n Lead by Example\\n라포랩스의 리더쉽은 권위나 직급에서 오지 않고, 따르고 싶은 마음에서 옵니다. \\n때문에 라포랩스는 부여되기보다, 직접 얻어내는 리더쉽을 추구합니다. 리더는 우리가 중요시하는 가치를 가장 잘 실천하는 사람들이며, 이를 통해 팀원들에게 존경과 존중을 얻을만한 사람이 되어야 합니다",', metadata={'source': 'data/라포랩스.json'})

# %% [markdown]
# 03 ChromaDB 생성
#
# 텍스트를 임베딩한다.
# db 폴더에 데이터 저장
# db 초기화
# db 폴더로부터 db로드

# %%
os.environ['OPENAI_API_KEY'] = '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'

# %%
persist_directory='db'

embedding = OpenAIEmbeddings()

vectordb = Chroma.from_documents(
    documents=texts,
    embedding=embedding,
    persist_directory=persist_directory
)

# %%
vectordb.persist() # 초기화
vectordb=None

# %%
vectordb = Chroma( # 기존 벡터 DB 로드
    persist_directory=persist_directory,
    embedding_function=embedding
)

# %% [markdown]
# ## 검색기

# %%
retriever = vectordb.as_retriever(search_kwargs={"k": 3}) # 유사도 상위 3개만 반환

# %%
docs = retriever.get_relevant_documents("재택근무, 유연 근무제")

for doc in docs:
    print(doc.metadata["source"])
# Out:
# txt_data/배민 프랜차이즈시스템.txt
# txt_data/라포랩스.txt
# txt_data/왓챠.txt

# %% [markdown]
# 상위 3개의 키워드와 연관성 있는 기업들 뽑아서 리스트에 저장하기

# %%
source_list = []

for doc in docs:
    source = doc.metadata["source"]
    cleaned_source = source.replace("txt_data/", "").replace(".txt", "")
    source_list.append(cleaned_source)


print(source_list)
# Out:
# ['배민 프랜차이즈시스템', '라포랩스', '왓챠']

# %%
text = ""

# source_list에 있는 각 기업명에 대하여
for source in source_list:
    # 파일명을 생성합니다.
    file_name = f"txt_data/{source}.txt"
    
    # 파일을 읽고 내용을 text 변수에 추가합니다.
    with open(file_name, 'r', encoding='utf-8') as f:
        text += f.read()

# text 변수를 출력하여 확인합니다.
print(text)
# Out:
# corp_name, value, intro, personality, benefit, culture, location, condition
# corp_name: 배민 프랜차이즈시스템
# value: 프랜차이즈시스템팀은 기획자와 개발자가 함께 모여 하나의 목표를 가지고 일하는 팀입니다.
# 사업/영업 조직과도 긴밀한 협업 관계를 바탕으로 배달의민족에 입점되어 있는 프랜차이즈 브랜드들이 배달의민족과 함께 더 큰 비즈니스 기회를 만들어 갈 수 있도록 함께 고민하며 일합니다.
# 직군에 상관없이 프랜차이즈 본사 담당자와도 직접 커뮤니케이션을 하며, 신뢰와 배려를 기반으로 한 상호 존중의 자세와 마음으로 파트너십을 만들어 가기 위해 노력합니다.
# intro: 배달의민족에는 전국의 수 많은 프랜차이즈가 입점되어 있습니다.
# 프랜차이즈 서비스는, 입점 중인 프랜차이즈 브랜드들이 배달의민족 앱을 통해 자사 홍보 및 브랜딩을 할 수 있도록 ‘브랜드관’ 을 운영 중이며, 사전예약 프로모션/브랜드할인쿠폰/브랜드상품권 등 다양한 형태의 프로모션 서비스를 제공 중입니다.
# 또한, 배달의민족 앱에서 발생한 주문을 프랜차이즈 본사에 직접 전달하는 ‘주문 중계’ 서비스가 있으며 프랜차이즈 기업 담당자의 ‘가게관리/메뉴관리/주문관리’ 등에 필요한 B2B 채널(외부 사용자용 관리자시스템)을 제공하기도 합니다.
# personality: 동료와 함께 배움과 공유를 통해서 같이 성장을 경험해 오신 분
# 혼자보다는 같이 기획하는 것을 즐기시는 분
# 문제해결 능력과 커뮤니케이션이 원활하신 분
# 새로운 서비스에 호기심이 많고 널리 공유하는걸 즐기시는 분
# 맡은 서비스를 고객중심에서 같이 고민하고 키워 나가실 분
# benefit: 4.5일 근무제(주35시간 근무)
# 월요병이 뭐예요? 매주 월요일은 오후 1시 출근!
# 화요일부터 금요일까지는 7.5시간 근무!
#
# 도서비 무한 지원
# 자기성장을 위한 도서는 금액과 상관없이 무한 지원!
# 단체상해보험지원
# ...

# %% [markdown]
# 세개의 기업 공통점 알려주기

# %%
from langchain.prompts import ChatPromptTemplate
from langchain.prompts.chat import SystemMessage, HumanMessagePromptTemplate
from langchain.chat_models import ChatOpenAI


template = ChatPromptTemplate.from_messages(
    [
        SystemMessage(
            content=(
                f"""
                Summarize the common benefits for employees who are working on {source_list} in Korean.
                
                - Tone : Humble
                - Style : MECE, accurate
                - Reader level : college student
                - Length : within 500 characters
                - Perspective : Recruiter
                - Format : markdown
                
                You MUST answer in Korean. 
                """
            )
        ),
        HumanMessagePromptTemplate.from_template("{text}"),
    ]
)

llm = ChatOpenAI(model="gpt-3.5-turbo-16k")

answer = llm(template.format_messages(text=text)).content

print(answer)
# Out:
# 배민 프랜차이즈시스템:
# - 4.5일 근무제(주35시간 근무)
# - 도서비 무한 지원
# - 단체상해보험지원
# - 우아한휴가/휴무 제도
# - 사내 동호회 지원
# - 개인노트북 지원
# - 우수사원 포상 제도
# - 각종 경조사 지원
# - 설/추석 명절 선물 지급
# - 임신기간 중 하루 2시간 유연/단축 근무
#
# 라포랩스:
# - 3년 또는 7년 이상의 백오피스 기획 또는 e-commerce 플랫폼 정책 수립 경험이 있는 분
# - 개인의 기여가 회사의 성장으로 이어지듯, 회사의 성장은 개인의 보상으로 이어짐
# - 경쟁력 있는 보상 패키지 제공
# - 전사 분기 목표 달성 시 구성원 전원에게 인센티브 지급
# - 주택 자금 및 사내 대출 지원
# - 업무와 관련된 도서/외부 교육/컨퍼런스/세미나 지원
# - 여름/겨울 방학 제공
# - 단체보험 및 건강검진 지원
# - 출산 및 양육 지원
# - 자율 출퇴근 제도
# - 쾌적한 업무 환경 제공
#
# 왓챠:
# - 3년 또는 7년 이상의 백오피스 기획 또는 e-commerce 플랫폼 정책 수립 경험이 있는 분
# - 업무용 Macbook Pro 제공
# - 업무환경 개인화 지원
# - 자율 출퇴근 및 재택근무 가능
# - 제휴 식당을 통한 점심식대 제공
# - 다양한 종류의 음료 제공
# - 리프레시 휴가 제도
# - 결혼기념일 스페셜 반차 제공
# - 업무에 적합한 사무공간 이용 가능
# - 업무용 장비 제공
# - 쾌적한 사무실 환경 제공

# %%
from langchain.prompts import ChatPromptTemplate
from langchain.prompts.chat import SystemMessage, HumanMessagePromptTemplate
from langchain.chat_models import ChatOpenAI


template = ChatPromptTemplate.from_messages(
    [
        SystemMessage(
            content=(
                f"""
                Write me the resume for {source_list} in Korean.
                
                There are 3 common questions for the resume that you should answer.
                1. Write down the motivation for applying to the company within 800 characters
                2. Please tell me your own experience related to the job. (Project, with history)
                3. Please tell me the value you want to create in the future at this company
                
                - Tone : Humble
                - Style : MECE, accurate
                - Reader level : New employee
                - Perspective : Recruiter
                - Format : markdown
                
                You MUST answer in Korean. 
                """
            )
        ),
        HumanMessagePromptTemplate.from_template("{text}"),
    ]
)

llm = ChatOpenAI(model="gpt-3.5-turbo-16k")

answer = llm(template.format_messages(text=text)).content

print(answer)
# Out:
# ## 배민 프랜차이즈시스템
#
# ### 지원 동기
#
# 배민 프랜차이즈시스템에 지원한 동기는 다음과 같습니다.
#
# 배달의민족은 현재 전국에 많은 프랜차이즈 브랜드가 입점되어 있습니다. 저는 배달의민족과 함께 프랜차이즈 브랜드들이 더 큰 비즈니스 기회를 찾을 수 있도록 도와주는 프랜차이즈시스템팀에서 일하고 싶습니다. 이 팀은 기획자와 개발자가 함께 일하며 하나의 목표를 가지고 있으며, 배달의민족과 프랜차이즈 브랜드들 사이의 협업을 통해 더 큰 성과를 이끌어 내고자 합니다.
#
# 또한, 이 회사에서는 직군에 상관없이 프랜차이즈 본사 담당자와 직접 커뮤니케이션을 하며 파트너십을 만들어 가는 것이 중요하다고 생각합니다. 저는 상호 존중과 신뢰를 기반으로 한 커뮤니케이션을 통해 파트너들과 함께 성장하고 발전해 나가고 싶습니다.
#
# ### 경험
#
# 저는 이전에 백오피스 기획 및 e-commerce 플랫폼 정책 수립과 관련된 프로젝트에 참여한 경험이 있습니다. 이 프로젝트에서는 기획 단계부터 참여하여 프로젝트 목표를 설정하고, 요구사항을 분석하여 정책을 수립하였습니다. 또한, 이를 바탕으로 프로토타입과 와이어프레임을 작성하여 개발팀과 원활한 커뮤니케이션을 진행하였습니다. 이 경험을 통해 비즈니스 도메인과 정책을 이해하고 도식화할 수 있는 능력을 갖췄습니다.
#
# ### 가치창출
#
# 배민 프랜차이즈시스템팀에서 제가 창출하고자 하는 가치는 다음과 같습니다.
#
# ...

# %% [markdown]
# ## 체인 제작 -> 이거 없앨까 ㅅㅂ?

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm=OpenAI(),
    chain_type="stuff",
    retriever=retriever,
    return_source_documents=True # 원본 문서 함께 반환
)

# %%
def process_llm_response(llm_response):
    print(llm_response['result'])
    print('\n\nSources')
    for source in llm_response['source_documents']:
        print(source.metadata['source'])

# %% [markdown]
# 쿼리 쏘기

# %%
query = "talk watcha"
llm_response = qa_chain(query)
process_llm_response(llm_response)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[22], line 2
#       1 query = "talk watcha"
# ----> 2 llm_response = qa_chain(query)
#       3 process_llm_response(llm_response)
#
# File /opt/homebrew/anaconda3/envs/my_env/lib/python3.11/site-packages/langchain/chains/base.py:282, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     280 except (KeyboardInterrupt, Exception) as e:
#     281     run_manager.on_chain_error(e)
# --> 282     raise e
#     283 run_manager.on_chain_end(outputs)
#     284 final_outputs: Dict[str, Any] = self.prep_outputs(
#     285     inputs, outputs, return_only_outputs
#     286 )
#
# File /opt/homebrew/anaconda3/envs/my_env/lib/python3.11/site-packages/langchain/chains/base.py:276, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
# ...

# %% [markdown]
# ## 요약하기

# %%
from langchain.prompts import ChatPromptTemplate
from langchain.prompts.chat import SystemMessage, HumanMessagePromptTemplate
from langchain.chat_models import ChatOpenAI


template = ChatPromptTemplate.from_messages(
    [
        SystemMessage(
            content=(
                f"""
                Summarize the common issues based on the news headlines of stocks which are best 5 influential components of {CONFIG.etf_tkr} in Korean.
                
                - Tone : Humble
                - Style : MECE, accurate
                - Reader level : college student
                - Length : within 500 characters
                - Perspective : Mckinsey&Company senior consultant
                - Format : markdown
                
                You MUST answer in Korean. 
                """
            )
        ),
        HumanMessagePromptTemplate.from_template("{text}"),
    ]
)

llm = ChatOpenAI(model="gpt-3.5-turbo-16k")

answer = llm(template.format_messages(text=text)).content

print(answer)
